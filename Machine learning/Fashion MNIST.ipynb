# %%
import numpy as np
from tensorflow import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import utils
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax'),
])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5003 - accuracy: 0.8249
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3790 - accuracy: 0.8630
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3417 - accuracy: 0.8750
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3183 - accuracy: 0.8828
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2980 - accuracy: 0.8902
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2830 - accuracy: 0.8960
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2725 - accuracy: 0.8997
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2590 - accuracy: 0.9031
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2517 - accuracy: 0.9059
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2409 - accuracy: 0.9094

# %%
predictions = model.predict(x_test)

# %%
val = 0
predictions[val]
# Out:
# array([9.1710183e-07, 5.2072509e-11, 3.0893649e-10, 1.1824411e-10,
#        3.8201165e-12, 2.3802757e-05, 1.4295633e-08, 1.9123126e-03,
#        2.5887479e-08, 9.9806291e-01], dtype=float32)

# %%
plt.imshow(x_test[val], cmap=plt.cm.binary)
plt.colorbar()
class_names = ['Футболка', 'Штаны', 'Свитер', 'Платье', 'Плащ', 'Сандали', 'Рубашка', 'Кроссовки', 'Сумка', 'Ботинки']
print(class_names[np.argmax(predictions[val])])
# Out:
# Ботинки

# %%
np.argmax(predictions[val])
# Out:
# 9

# %%
y_test[val]
# Out:
# 9
